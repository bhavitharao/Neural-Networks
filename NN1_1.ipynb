# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
import tensorflow as tf

# %%
df = pd.read_csv('Problem1 - Sunspots.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
print(df.isnull().sum())
# Out:
# Unnamed: 0                           0
# Date                                 0
# Monthly Mean Total Sunspot Number    0
# dtype: int64

# %%
X = df.drop(['Date', 'Monthly Mean Total Sunspot Number'], axis=1)
y = df['Monthly Mean Total Sunspot Number']

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(units = 1, activation = 'relu', input_shape=(X_train.shape[1],)))
#model.add(keras.layers.Dense(units = 16, activation = 'relu'))
model.add(keras.layers.Dense(units = 32, activation = 'relu'))
#model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 128, activation = 'relu'))
model.add(keras.layers.Dense(units = 256, activation = 'linear'))
model.add(keras.layers.Dense(units = 512, activation = 'linear'))


model.add(keras.layers.Dense(units = 256, activation = 'linear'))
model.add(keras.layers.Dense(units = 128, activation = 'relu'))
#model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 32, activation = 'relu'))
#model.add(keras.layers.Dense(units = 16, activation = 'relu'))
model.add(keras.layers.Dense(units = 1, activation = 'linear'))
model.compile(loss='mse', optimizer='rmsprop')

# %%
model.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_302 (Dense)           (None, 1)                 2
#
#  dense_303 (Dense)           (None, 32)                64
#
#  dense_304 (Dense)           (None, 128)               4224
#
#  dense_305 (Dense)           (None, 256)               33024
#
#  dense_306 (Dense)           (None, 512)               131584
#
#  dense_307 (Dense)           (None, 256)               131328
#
#  dense_308 (Dense)           (None, 128)               32896
#
#  dense_309 (Dense)           (None, 32)                4128
#
#  dense_310 (Dense)           (None, 1)                 33
#
# =================================================================
# Total params: 337,283
# Trainable params: 337,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 82/82 [==============================] - 1s 15ms/step - loss: 4081.3633
# Epoch 2/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4143.7051
# Epoch 3/100
# 82/82 [==============================] - 1s 10ms/step - loss: 4094.8364
# Epoch 4/100
# 82/82 [==============================] - 1s 14ms/step - loss: 4079.6069
# Epoch 5/100
# 82/82 [==============================] - 1s 15ms/step - loss: 4127.9336
# Epoch 6/100
# 82/82 [==============================] - 1s 15ms/step - loss: 4097.2983
# Epoch 7/100
# 82/82 [==============================] - 1s 10ms/step - loss: 4094.1299
# Epoch 8/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4113.8623
# Epoch 9/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4068.1611
# Epoch 10/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4094.9697
# Epoch 11/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4107.3574
# Epoch 12/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4053.4021
# Epoch 13/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4043.1987
# Epoch 14/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4111.8359
# Epoch 15/100
# 82/82 [==============================] - 1s 10ms/step - loss: 4057.6973
# Epoch 16/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4075.3005
# Epoch 17/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4032.7451
# Epoch 18/100
# 82/82 [==============================] - 1s 10ms/step - loss: 4058.0156
# Epoch 19/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4050.1936
# Epoch 20/100
# 82/82 [==============================] - 1s 18ms/step - loss: 4097.2432
# Epoch 21/100
# 82/82 [==============================] - 2s 19ms/step - loss: 4047.6326
# Epoch 22/100
# 82/82 [==============================] - 1s 13ms/step - loss: 4066.3369
# Epoch 23/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4031.9995
# Epoch 24/100
# 82/82 [==============================] - 1s 10ms/step - loss: 4053.8391
# Epoch 25/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4011.9609
# Epoch 26/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4041.0679
# Epoch 27/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4035.8047
# Epoch 28/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4048.6194
# Epoch 29/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4041.8687
# Epoch 30/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4047.1975
# Epoch 31/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4017.4429
# Epoch 32/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4042.4705
# Epoch 33/100
# 82/82 [==============================] - 1s 10ms/step - loss: 4001.3955
# Epoch 34/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4059.1416
# Epoch 35/100
# 82/82 [==============================] - 1s 11ms/step - loss: 4049.4124
# Epoch 36/100
# 82/82 [==============================] - 1s 15ms/step - loss: 4006.7102
# Epoch 37/100
# 82/82 [==============================] - 1s 16ms/step - loss: 4029.1289
# Epoch 38/100
# 82/82 [==============================] - 1s 11ms/step - loss: 4036.3572
# Epoch 39/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3999.0823
# Epoch 40/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4035.2427
# Epoch 41/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4016.2446
# Epoch 42/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4010.3694
# Epoch 43/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4019.2695
# Epoch 44/100
# 82/82 [==============================] - 1s 10ms/step - loss: 4001.9958
# Epoch 45/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3991.2310
# Epoch 46/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3996.6211
# Epoch 47/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3983.2417
# Epoch 48/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3996.1787
# Epoch 49/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4003.6111
# Epoch 50/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3933.4514
# Epoch 51/100
# 82/82 [==============================] - 1s 13ms/step - loss: 3989.1006
# Epoch 52/100
# 82/82 [==============================] - 1s 15ms/step - loss: 3998.0310
# Epoch 53/100
# 82/82 [==============================] - 1s 15ms/step - loss: 3981.3330
# Epoch 54/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3974.2764
# Epoch 55/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3993.5034
# Epoch 56/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4002.0588
# Epoch 57/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3964.9846
# Epoch 58/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3996.3376
# Epoch 59/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3989.8442
# Epoch 60/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4011.1340
# Epoch 61/100
# 82/82 [==============================] - 1s 9ms/step - loss: 4002.1611
# Epoch 62/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3976.9553
# Epoch 63/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3996.9197
# Epoch 64/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3990.9812
# Epoch 65/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3972.6875
# Epoch 66/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3978.7920
# Epoch 67/100
# 82/82 [==============================] - 1s 13ms/step - loss: 3966.4146
# Epoch 68/100
# 82/82 [==============================] - 1s 15ms/step - loss: 3976.4163
# Epoch 69/100
# 82/82 [==============================] - 2s 23ms/step - loss: 3968.0620
# Epoch 70/100
# 82/82 [==============================] - 1s 14ms/step - loss: 3967.3801
# Epoch 71/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3970.1787
# Epoch 72/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3990.5088
# Epoch 73/100
# 82/82 [==============================] - 1s 16ms/step - loss: 3951.4712
# Epoch 74/100
# 82/82 [==============================] - 2s 19ms/step - loss: 3960.8523
# Epoch 75/100
# 82/82 [==============================] - 1s 14ms/step - loss: 3976.9636
# Epoch 76/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3957.7000
# Epoch 77/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3973.4993
# Epoch 78/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3937.5012
# Epoch 79/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3951.4304
# Epoch 80/100
# 82/82 [==============================] - 1s 14ms/step - loss: 3968.8452
# Epoch 81/100
# 82/82 [==============================] - 1s 15ms/step - loss: 3964.5447
# Epoch 82/100
# 82/82 [==============================] - 1s 15ms/step - loss: 3949.4385
# Epoch 83/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3983.1799
# Epoch 84/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3988.0447
# Epoch 85/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3941.2771
# Epoch 86/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3978.5767
# Epoch 87/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3957.9131
# Epoch 88/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3989.4543
# Epoch 89/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3959.4426
# Epoch 90/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3965.8782
# Epoch 91/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3958.5564
# Epoch 92/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3958.4995
# Epoch 93/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3966.4426
# Epoch 94/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3935.8142
# Epoch 95/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3931.0925
# Epoch 96/100
# 82/82 [==============================] - 1s 15ms/step - loss: 3962.5466
# Epoch 97/100
# 82/82 [==============================] - 1s 15ms/step - loss: 3951.7258
# Epoch 98/100
# 82/82 [==============================] - 1s 13ms/step - loss: 3919.9648
# Epoch 99/100
# 82/82 [==============================] - 1s 9ms/step - loss: 3947.0444
# Epoch 100/100
# 82/82 [==============================] - 1s 10ms/step - loss: 3929.9321

# %%
y_predicted_test = model.predict(X_test)
# Out:
# 21/21 [==============================] - 0s 4ms/step

# %%
plt.scatter(X_train, y_train, label='Actual', color='blue')

plt.scatter(X_test, y_predicted_test, label='Predicted', color='red', marker='x')
plt.xlabel('X Data')
plt.ylabel('Y Data')
plt.title('Scatter Plot: Actual vs. Predicted (Test Data)')
plt.legend()
plt.grid()
plt.show()
